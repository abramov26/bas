# %% [markdown]
# # БАС. Динамика. Абрамов В. В. ПИ-423

# %% [markdown]
# ## Исходные данные

# %% [markdown]
# **Задание**
#
# Выполните все шаги для своего варианта и загрузите в СДО ссылку на блокнот.

# %% [markdown]
# Вариант задания: 2 (номер зачётки 19130172).
#
# Анализируемая компания: Gazprom PAO (GAZP)
#
# https://www.investing.com/equities/gazprom_rts

# %%
# подключаем библиотеку для работы с таблицами
import pandas as pd

# Читаем таблицу CSV в переменную gazp
# Копируем путь к файлу и вставляем как аргумент функции READ_CSV
# Далее по тексту используйте биржевой тикер своего актива в названиях и заголовках
gazp = pd.read_csv("/content/GAZP Historical Data.csv", parse_dates=['Date'], usecols=range(5), index_col=0)

# Проверяем, правильно ли прочитаны данные
gazp.head(3)
# Out:
#              Price    Open    High     Low
# Date
# 2023-04-06  171.60  174.02  175.00  171.30
# 2023-04-05  173.86  172.55  174.48  170.58
# 2023-04-04  172.55  171.00  176.00  170.14

# %%
# Тип данных по столбцам
gazp.dtypes
# Out:
# Price    float64
# Open     float64
# High     float64
# Low      float64
# dtype: object

# %%
# Переименуем столбец Price в Close
gazp.rename(columns={"Price": "Close"}, inplace=True)

# Проверяем, правильно ли переименовали столбец
gazp.head(3)
# Out:
#              Close    Open    High     Low
# Date
# 2023-04-06  171.60  174.02  175.00  171.30
# 2023-04-05  173.86  172.55  174.48  170.58
# 2023-04-04  172.55  171.00  176.00  170.14

# %%
# Установим библиотеку биржевых гарфиков
# !pip install mplfinance
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# Подключаем библиотеку для построения биржевых графиков
import mplfinance as mpf

# %%
# Построим свечной график
# Наносим скользящие средние с периодами 51 и 200 дней
mpf.plot(gazp, warn_too_much_data=20000, figsize=(18, 6), mav=(51, 201), 
         title="GAZP + SMA 51 + SMA 200", type='candle')
